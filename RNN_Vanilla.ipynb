# %%
# date set is balanced

# %%
# library import
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
from torchvision import datasets

import numpy as np
import matplotlib.pyplot as plt

# %%
# define hyperparameters and functions
batch_size = 100
num_epoches = 100

window_step = 5
window_length = 10

learning_rate = 1e-3
betas=(0.9, 0.999)
weight_decay=1e-3


index = np.arange(2115)
np.random.shuffle(index)
training_index, valid_index = index[:1715], index[1715:]

train_acc = []
test_acc = []


use_gpu = torch.cuda.is_available()  # determine whether it has gpu speed up


def plot_acc(train_acc, test_acc):
    plt.plot(test_acc, label = "test")
    plt.plot(train_acc, label = "train")
    plt.xlabel("eopch")
    plt.ylabel("accuracy")
    plt.legend()
    plt.title("The accuracy against epoch")
    plt.show()


def flatten(x):
    """
    Input:
    - Tensor of shape (N, D1, ..., DM)
    Output:
    - Tensor of shape (N, D1 * ... * DM)
    """
    x_shape = x.size()
    new_shape = 1
    for i in range(len(x_shape) - 1):
        new_shape *= x_shape[i + 1]
    x_flat = x.reshape((x_shape[0],new_shape))
    return x_flat

# %%
# load data into environment
X_test = np.load("data/X_test.npy")
y_test = np.load("data/y_test.npy")
person_train_valid = np.load("data/person_train_valid.npy")
X_train_valid = np.load("data/X_train_valid.npy")
y_train_valid = np.load("data/y_train_valid.npy")
person_test = np.load("data/person_test.npy")

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 25, 1000)
# Test data shape: (443, 25, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %%
# transform data into pytorch form
# extract first 22 signals out of 25 signals
X_train_valid = X_train_valid[:, :22, :]
X_train = X_train_valid[training_index]
X_valid = X_train_valid[valid_index]
X_test = X_test[:, :22, :]

y_train = y_train_valid[training_index]
y_valid = y_train_valid[valid_index]


trainset = torch.utils.data.TensorDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train - 769).long())
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

validset = torch.utils.data.TensorDataset(torch.from_numpy(X_valid).float(), torch.from_numpy(y_valid - 769).long())
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size, shuffle=False, num_workers=2)

testset = torch.utils.data.TensorDataset(torch.from_numpy(X_test).float(), torch.from_numpy(y_test - 769).long())
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# %%
# network architecture
class eeg_lstm(nn.Module):
     def __init__(self, in_feature=22, hidden_feature=32, num_class=4, signal_length=1000):
          super(eeg_lstm, self).__init__()
          self.rnn = nn.LSTM(input_size=in_feature, hidden_size=hidden_feature, num_layers=1) #using 5 layers lstm
          self.relu = nn.ReLU()
          self.dropout = nn.Dropout(0.5)
          self.classifier = nn.Linear(hidden_feature*signal_length, num_class) #using linear to classify the output
          
     def forward(self, x):
          out, _ = self.rnn(x) #使用默认的隐藏状态，得到的out是（1000， batch， hidden_feature）
          #print(out.shape)
          out = self.dropout(out)
          out = self.relu(out)
          out = self.dropout(out)
          #out = out[-101:-1,:,:]#取序列中的最后一个，大小是（batch， hidden_feature)
          out = flatten(out.permute(1, 0, 2))
          #print(out.shape)
          out = self.classifier(out) #得到分类结果
          #tag_score = F.log_softmax(out, dim=1)
          return out

# %%
# initiate lstm network
model = eeg_lstm()  
if use_gpu:
    model = model.cuda()


# define loss function and optimizer
criterion = nn.CrossEntropyLoss()
# parameters in Adam could be tuned
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=betas, weight_decay=weight_decay)

# %%
# start training and evaluating models
for epoch in range(num_epoches):  # again, normally you would NOT do 300 epochs, it is toy data
    model.train()
    print('epoch {}'.format(epoch + 1))
    print('*' * 10)
    running_loss = 0.0
    running_acc = 0.0
    for batch_idx, (signals, tags) in enumerate(trainloader):
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        model.zero_grad()

        # Step 2. Get our inputs ready for the network, that is, turn them into
        # Tensors of word indices.
        signals = signals.squeeze(1)
        signals = signals.permute(2, 0, 1)
        if use_gpu:
            signals = Variable(signals).cuda()
            tags = Variable(tags).cuda()
        else:
            signals = Variable(signals)
            tags = Variable(tags)

        # Step 3. Run our forward pass.
        tag_scores = model(signals)
        
        # Step 4. Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()
        loss = criterion(tag_scores, tags)
        running_loss += loss.data.item() * tags.size(0)
        _, pred = torch.max(tag_scores, 1)
        num_correct = (pred == tags).sum()
        running_acc += num_correct.data.item()
        # 向后传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print('Finish {} epoch, Loss: {:.6f}, Acc: {:.6f}'.format(
        epoch + 1, running_loss / (len(X_train)), running_acc / (len(
            X_train))))
    train_acc.append(running_acc / (len(X_train)))
    
    model.eval()
    eval_loss = 0.
    eval_acc = 0.
    for batch_idx, (signals, tags) in enumerate(validloader):
        
        signals = signals.squeeze(1)
        signals = signals.permute(2, 0, 1)
        if use_gpu:
            signals = Variable(signals).cuda()
            tags = Variable(tags).cuda()
        else:
            signals = Variable(signals)
            tags = Variable(tags)

        tag_scores = model(signals)
        loss = criterion(tag_scores, tags)
        eval_loss += loss.data.item() * tags.size(0)
        _, pred = torch.max(tag_scores, 1)
        num_correct = (pred == tags).sum()
        eval_acc += num_correct.data.item()
    print('Validation Loss: {:.6f}, Acc: {:.6f}'.format(eval_loss / (len(
        X_valid)), eval_acc / (len(X_valid))))
    test_acc.append(eval_acc / (len(X_valid)))
    print()

plot_acc(train_acc, test_acc)

file = open('vanilla.txt', 'a+')
s = ""
for e in test_acc:
  s+=str(e)
  s+=','
s+='\n'
file.writelines(s)
file.close()

eval_loss = 0.
eval_acc = 0.
for batch_idx, (signals, tags) in enumerate(testloader):
        
    signals = signals.squeeze(1)
    signals = signals.permute(2, 0, 1)
    if use_gpu:
        signals = Variable(signals).cuda()
        tags = Variable(tags).cuda()
    else:
        signals = Variable(signals)
        tags = Variable(tags)

    tag_scores = model(signals)
    loss = criterion(tag_scores, tags)
    eval_loss += loss.data.item() * tags.size(0)
    _, pred = torch.max(tag_scores, 1)
    num_correct = (pred == tags).sum()
    eval_acc += num_correct.data.item()
print('Test Loss: {:.6f}, Acc: {:.6f}'.format(eval_loss / (len(
        X_test)), eval_acc / (len(X_test))))
print()
# Out:
# epoch 1
# **********
# Finish 1 epoch, Loss: 1.486628, Acc: 0.304373
# Validation Loss: 1.413218, Acc: 0.327500
#
# epoch 2
# **********
# Finish 2 epoch, Loss: 1.106557, Acc: 0.520117
# Validation Loss: 1.237869, Acc: 0.420000
#
# epoch 3
# **********
# Finish 3 epoch, Loss: 0.864807, Acc: 0.657143
# Validation Loss: 1.406175, Acc: 0.367500
#
# epoch 4
# **********
# Finish 4 epoch, Loss: 0.726084, Acc: 0.719534
# Validation Loss: 1.217888, Acc: 0.482500
#
# epoch 5
# **********
# Finish 5 epoch, Loss: 0.570760, Acc: 0.805831
# Validation Loss: 1.154022, Acc: 0.515000
#
# epoch 6
# **********
# Finish 6 epoch, Loss: 0.462059, Acc: 0.850729
# Validation Loss: 1.155390, Acc: 0.520000
#
# epoch 7
# **********
# Finish 7 epoch, Loss: 0.393095, Acc: 0.883965
# Validation Loss: 1.206740, Acc: 0.492500
#
# epoch 8
# **********
# Finish 8 epoch, Loss: 0.348964, Acc: 0.885131
# Validation Loss: 1.212163, Acc: 0.497500
#
# epoch 9
# **********
# Finish 9 epoch, Loss: 0.300106, Acc: 0.906706
# Validation Loss: 1.186244, Acc: 0.512500
#
# epoch 10
# **********
# Finish 10 epoch, Loss: 0.266120, Acc: 0.924781
# Validation Loss: 1.186735, Acc: 0.532500
#
# epoch 11
# **********
# Finish 11 epoch, Loss: 0.263149, Acc: 0.917784
# Validation Loss: 1.188475, Acc: 0.522500
#
# epoch 12
# **********
# Finish 12 epoch, Loss: 0.217760, Acc: 0.944606
# Validation Loss: 1.275288, Acc: 0.502500
#
# epoch 13
# **********
# Finish 13 epoch, Loss: 0.222313, Acc: 0.932945
# Validation Loss: 1.252454, Acc: 0.512500
#
# epoch 14
# **********
# Finish 14 epoch, Loss: 0.204189, Acc: 0.948105
# Validation Loss: 1.219857, Acc: 0.517500
#
# epoch 15
# **********
# Finish 15 epoch, Loss: 0.188651, Acc: 0.945773
# Validation Loss: 1.237082, Acc: 0.532500
#
# epoch 16
# **********
# Finish 16 epoch, Loss: 0.175569, Acc: 0.952770
# Validation Loss: 1.256956, Acc: 0.520000
#
# epoch 17
# **********
# Finish 17 epoch, Loss: 0.172094, Acc: 0.949854
# Validation Loss: 1.274337, Acc: 0.547500
#
# epoch 18
# **********
# Finish 18 epoch, Loss: 0.170228, Acc: 0.946356
# Validation Loss: 1.247648, Acc: 0.525000
#
# epoch 19
# **********
# Finish 19 epoch, Loss: 0.163396, Acc: 0.949854
# Validation Loss: 1.319053, Acc: 0.517500
#
# epoch 20
# **********
# Finish 20 epoch, Loss: 0.161931, Acc: 0.951020
# Validation Loss: 1.232639, Acc: 0.535000
#
# epoch 21
# **********
# Finish 21 epoch, Loss: 0.143879, Acc: 0.957434
# Validation Loss: 1.266005, Acc: 0.530000
#
# epoch 22
# **********
# Finish 22 epoch, Loss: 0.133304, Acc: 0.966181
# Validation Loss: 1.258206, Acc: 0.545000
#
# epoch 23
# **********
# Finish 23 epoch, Loss: 0.135869, Acc: 0.962099
# Validation Loss: 1.292893, Acc: 0.520000
#
# epoch 24
# **********
# Finish 24 epoch, Loss: 0.122139, Acc: 0.965015
# Validation Loss: 1.333397, Acc: 0.532500
#
# epoch 25
# **********
# Finish 25 epoch, Loss: 0.140188, Acc: 0.956268
# Validation Loss: 1.281718, Acc: 0.537500
#
# epoch 26
# **********
# Finish 26 epoch, Loss: 0.118287, Acc: 0.965015
# Validation Loss: 1.284020, Acc: 0.542500
#
# epoch 27
# **********
# Finish 27 epoch, Loss: 0.112903, Acc: 0.967347
# Validation Loss: 1.284210, Acc: 0.540000
#
# epoch 28
# **********
# Finish 28 epoch, Loss: 0.097786, Acc: 0.969679
# Validation Loss: 1.338140, Acc: 0.512500
#
# epoch 29
# **********
# Finish 29 epoch, Loss: 0.117178, Acc: 0.966764
# Validation Loss: 1.334147, Acc: 0.515000
#
# epoch 30
# **********
# Finish 30 epoch, Loss: 0.122564, Acc: 0.959184
# Validation Loss: 1.295604, Acc: 0.550000
#
# epoch 31
# **********
# Finish 31 epoch, Loss: 0.108002, Acc: 0.967930
# Validation Loss: 1.295977, Acc: 0.525000
#
# epoch 32
# **********
# Finish 32 epoch, Loss: 0.088452, Acc: 0.975510
# Validation Loss: 1.300537, Acc: 0.530000
#
# epoch 33
# **********
# Finish 33 epoch, Loss: 0.092201, Acc: 0.972012
# Validation Loss: 1.306026, Acc: 0.540000
#
# epoch 34
# **********
# Finish 34 epoch, Loss: 0.095579, Acc: 0.974344
# Validation Loss: 1.359308, Acc: 0.527500
#
# epoch 35
# **********
# Finish 35 epoch, Loss: 0.089042, Acc: 0.972595
# Validation Loss: 1.373729, Acc: 0.535000
#
# epoch 36
# **********
# Finish 36 epoch, Loss: 0.085833, Acc: 0.974344
# Validation Loss: 1.365178, Acc: 0.530000
#
# epoch 37
# **********
# Finish 37 epoch, Loss: 0.094547, Acc: 0.969679
# Validation Loss: 1.304267, Acc: 0.525000
#
# epoch 38
# **********
# Finish 38 epoch, Loss: 0.084703, Acc: 0.972012
# Validation Loss: 1.417944, Acc: 0.517500
#
# epoch 39
# **********
# Finish 39 epoch, Loss: 0.097486, Acc: 0.967347
# Validation Loss: 1.354207, Acc: 0.555000
#
# epoch 40
# **********
# Finish 40 epoch, Loss: 0.089608, Acc: 0.966181
# Validation Loss: 1.334950, Acc: 0.537500
#
# epoch 41
# **********
# Finish 41 epoch, Loss: 0.096332, Acc: 0.966764
# Validation Loss: 1.462281, Acc: 0.517500
#
# epoch 42
# **********
# Finish 42 epoch, Loss: 0.111625, Acc: 0.965598
# Validation Loss: 1.357004, Acc: 0.545000
#
# epoch 43
# **********
# Finish 43 epoch, Loss: 0.097865, Acc: 0.969679
# Validation Loss: 1.367407, Acc: 0.555000
#
# epoch 44
# **********
# Finish 44 epoch, Loss: 0.077919, Acc: 0.976676
# Validation Loss: 1.351038, Acc: 0.527500
#
# epoch 45
# **********
# Finish 45 epoch, Loss: 0.096604, Acc: 0.966764
# Validation Loss: 1.400363, Acc: 0.512500
#
# epoch 46
# **********
# Finish 46 epoch, Loss: 0.106272, Acc: 0.965015
# Validation Loss: 1.392613, Acc: 0.515000
#
# epoch 47
# **********
# Finish 47 epoch, Loss: 0.093863, Acc: 0.972595
# Validation Loss: 1.487335, Acc: 0.522500
#
# epoch 48
# **********
# Finish 48 epoch, Loss: 0.085236, Acc: 0.970845
# Validation Loss: 1.484740, Acc: 0.505000
#
# epoch 49
# **********
# Finish 49 epoch, Loss: 0.077252, Acc: 0.975510
# Validation Loss: 1.475049, Acc: 0.522500
#
# epoch 50
# **********
# Finish 50 epoch, Loss: 0.071675, Acc: 0.978426
# Validation Loss: 1.442089, Acc: 0.507500
#
# epoch 51
# **********
# Finish 51 epoch, Loss: 0.081895, Acc: 0.975510
# Validation Loss: 1.427691, Acc: 0.517500
#
# epoch 52
# **********
# Finish 52 epoch, Loss: 0.096907, Acc: 0.965598
# Validation Loss: 1.504804, Acc: 0.517500
#
# epoch 53
# **********
# Finish 53 epoch, Loss: 0.085328, Acc: 0.972012
# Validation Loss: 1.492691, Acc: 0.510000
#
# epoch 54
# **********
# Finish 54 epoch, Loss: 0.085814, Acc: 0.970845
# Validation Loss: 1.441322, Acc: 0.532500
#
# epoch 55
# **********
# Finish 55 epoch, Loss: 0.066707, Acc: 0.979592
# Validation Loss: 1.446898, Acc: 0.520000
#
# epoch 56
# **********
# Finish 56 epoch, Loss: 0.074779, Acc: 0.976093
# Validation Loss: 1.464224, Acc: 0.532500
#
# epoch 57
# **********
# Finish 57 epoch, Loss: 0.079003, Acc: 0.973178
# Validation Loss: 1.486336, Acc: 0.525000
#
# epoch 58
# **********
# Finish 58 epoch, Loss: 0.094058, Acc: 0.968513
# Validation Loss: 1.567348, Acc: 0.527500
#
# epoch 59
# **********
# Finish 59 epoch, Loss: 0.089326, Acc: 0.971429
# Validation Loss: 1.587107, Acc: 0.502500
#
# epoch 60
# **********
# Finish 60 epoch, Loss: 0.093973, Acc: 0.965015
# Validation Loss: 1.476002, Acc: 0.517500
#
# epoch 61
# **********
# Finish 61 epoch, Loss: 0.071962, Acc: 0.974344
# Validation Loss: 1.490780, Acc: 0.515000
#
# epoch 62
# **********
# Finish 62 epoch, Loss: 0.077096, Acc: 0.975510
# Validation Loss: 1.499294, Acc: 0.520000
#
# epoch 63
# **********
# Finish 63 epoch, Loss: 0.077861, Acc: 0.972012
# Validation Loss: 1.502697, Acc: 0.525000
#
# epoch 64
# **********
# Finish 64 epoch, Loss: 0.076943, Acc: 0.972012
# Validation Loss: 1.562832, Acc: 0.515000
#
# epoch 65
# **********
# Finish 65 epoch, Loss: 0.080536, Acc: 0.974344
# Validation Loss: 1.503807, Acc: 0.550000
#
# epoch 66
# **********
# Finish 66 epoch, Loss: 0.063828, Acc: 0.977259
# Validation Loss: 1.575483, Acc: 0.500000
#
# epoch 67
# **********
# Finish 67 epoch, Loss: 0.089817, Acc: 0.971429
# Validation Loss: 1.464105, Acc: 0.520000
#
# epoch 68
# **********
# Finish 68 epoch, Loss: 0.084153, Acc: 0.971429
# Validation Loss: 1.482976, Acc: 0.517500
#
# epoch 69
# **********
# Finish 69 epoch, Loss: 0.071397, Acc: 0.975510
# Validation Loss: 1.519996, Acc: 0.542500
#
# epoch 70
# **********
# Finish 70 epoch, Loss: 0.088749, Acc: 0.972012
# Validation Loss: 1.505699, Acc: 0.532500
#
# epoch 71
# **********
# Finish 71 epoch, Loss: 0.057906, Acc: 0.981924
# Validation Loss: 1.548370, Acc: 0.522500
#
# epoch 72
# **********
# Finish 72 epoch, Loss: 0.072167, Acc: 0.975510
# Validation Loss: 1.542810, Acc: 0.510000
#
# epoch 73
# **********
# Finish 73 epoch, Loss: 0.093620, Acc: 0.965598
# Validation Loss: 1.569389, Acc: 0.535000
#
# epoch 74
# **********
# Finish 74 epoch, Loss: 0.089836, Acc: 0.967347
# Validation Loss: 1.524018, Acc: 0.532500
#
# epoch 75
# **********
# Finish 75 epoch, Loss: 0.074697, Acc: 0.972595
# Validation Loss: 1.517378, Acc: 0.552500
#
# epoch 76
# **********
# Finish 76 epoch, Loss: 0.090142, Acc: 0.966764
# Validation Loss: 1.521301, Acc: 0.557500
#
# epoch 77
# **********
# Finish 77 epoch, Loss: 0.081090, Acc: 0.970845
# Validation Loss: 1.550371, Acc: 0.540000
#
# epoch 78
# **********
# Finish 78 epoch, Loss: 0.076378, Acc: 0.974927
# Validation Loss: 1.567564, Acc: 0.550000
#
# epoch 79
# **********
# Finish 79 epoch, Loss: 0.097967, Acc: 0.966181
# Validation Loss: 1.602259, Acc: 0.550000
#
# epoch 80
# **********
# Finish 80 epoch, Loss: 0.112920, Acc: 0.964431
# Validation Loss: 1.615962, Acc: 0.532500
#
# epoch 81
# **********
# Finish 81 epoch, Loss: 0.110292, Acc: 0.962682
# Validation Loss: 1.576009, Acc: 0.525000
#
# epoch 82
# **********
# Finish 82 epoch, Loss: 0.101438, Acc: 0.962682
# Validation Loss: 1.564386, Acc: 0.522500
#
# epoch 83
# **********
# Finish 83 epoch, Loss: 0.089994, Acc: 0.967930
# Validation Loss: 1.566620, Acc: 0.545000
#
# epoch 84
# **********
# Finish 84 epoch, Loss: 0.076718, Acc: 0.974927
# Validation Loss: 1.540460, Acc: 0.532500
#
# epoch 85
# **********
# Finish 85 epoch, Loss: 0.079085, Acc: 0.970262
# Validation Loss: 1.537931, Acc: 0.535000
#
# epoch 86
# **********
# Finish 86 epoch, Loss: 0.070320, Acc: 0.978426
# Validation Loss: 1.604674, Acc: 0.530000
#
# epoch 87
# **********
# Finish 87 epoch, Loss: 0.070500, Acc: 0.974927
# Validation Loss: 1.552419, Acc: 0.540000
#
# epoch 88
# **********
# Finish 88 epoch, Loss: 0.077244, Acc: 0.971429
# Validation Loss: 1.561162, Acc: 0.535000
#
# epoch 89
# **********
# Finish 89 epoch, Loss: 0.055853, Acc: 0.983090
# Validation Loss: 1.509385, Acc: 0.545000
#
# epoch 90
# **********
# Finish 90 epoch, Loss: 0.077404, Acc: 0.974344
# Validation Loss: 1.542261, Acc: 0.537500
#
# epoch 91
# **********
# Finish 91 epoch, Loss: 0.085786, Acc: 0.971429
# Validation Loss: 1.528557, Acc: 0.552500
#
# epoch 92
# **********
# Finish 92 epoch, Loss: 0.064269, Acc: 0.979009
# Validation Loss: 1.512441, Acc: 0.535000
#
# epoch 93
# **********
# Finish 93 epoch, Loss: 0.074756, Acc: 0.976093
# Validation Loss: 1.535813, Acc: 0.535000
#
# epoch 94
# **********
# Finish 94 epoch, Loss: 0.083309, Acc: 0.970845
# Validation Loss: 1.527859, Acc: 0.535000
#
# epoch 95
# **********
# Finish 95 epoch, Loss: 0.074731, Acc: 0.979009
# Validation Loss: 1.610701, Acc: 0.530000
#
# epoch 96
# **********
# Finish 96 epoch, Loss: 0.084563, Acc: 0.973761
# Validation Loss: 1.566306, Acc: 0.537500
#
# epoch 97
# **********
# Finish 97 epoch, Loss: 0.051487, Acc: 0.986006
# Validation Loss: 1.537388, Acc: 0.532500
#
# epoch 98
# **********
# Finish 98 epoch, Loss: 0.071952, Acc: 0.974927
# Validation Loss: 1.589867, Acc: 0.550000
#
# epoch 99
# **********
# Finish 99 epoch, Loss: 0.066982, Acc: 0.976093
# Validation Loss: 1.618203, Acc: 0.535000
#
# epoch 100
# **********
# Finish 100 epoch, Loss: 0.066274, Acc: 0.979592
# Validation Loss: 1.588689, Acc: 0.532500
# Test Loss: 1.768370, Acc: 0.471783
