# %%
# date set is balanced

# %%
# library import
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
from torchvision import datasets

import numpy as np
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
# define hyperparameters and functions
batch_size = 100
num_epoches = 100

window_step = 5
window_length = 10

learning_rate = 1e-3
betas=(0.9, 0.999)
weight_decay=1e-3


index = np.arange(2115)
np.random.shuffle(index)
training_index, valid_index = index[:1715], index[1715:]

train_acc = []
test_acc = []


use_gpu = torch.cuda.is_available()  # determine whether it has gpu speed up


def plot_acc(train_acc, test_acc):
    plt.plot(test_acc, label = "test")
    plt.plot(train_acc, label = "train")
    plt.xlabel("eopch")
    plt.ylabel("accuracy")
    plt.legend()
    plt.title("The accuracy against epoch")
    plt.show()


def flatten(x):
    """
    Input:
    - Tensor of shape (N, D1, ..., DM)
    Output:
    - Tensor of shape (N, D1 * ... * DM)
    """
    x_shape = x.size()
    new_shape = 1
    for i in range(len(x_shape) - 1):
        new_shape *= x_shape[i + 1]
    x_flat = x.reshape((x_shape[0],new_shape))
    return x_flat
  
def sliding_window(length, shift, data):
    """
    Input:
    - raw eeg data
    Output:
    - processed window signals, everytime shifted with "shift" units, window length is "length"
    """
    p, e, d = data.shape
    
    if(d%shift==0):
        new_data_size = d//shift
        new_data = np.zeros((p, e, new_data_size))
        for i in range(d//shift):
            new_data[:, :, i] = np.mean(data[:, :, i*shift:(i+1)*shift+length], axis = 2)

    else:
        new_data_size = d//shift+1
        new_data = np.zeros((p, e, new_data_size))
        for i in range(d//shift):
            new_data[:, :, i] = np.mean(data[:, :, i*shift:(i+1)*shift+length], axis = 2)
        new_data[:, :, new_data_size-1] = np.mean(data[:, :, (new_data_size-1)*shift:], axis = 2)
    
    return new_data

# %%
# load data into environment
X_test = np.load("data/X_test.npy")
y_test = np.load("data/y_test.npy")
person_train_valid = np.load("data/person_train_valid.npy")
X_train_valid = np.load("data/X_train_valid.npy")
y_train_valid = np.load("data/y_train_valid.npy")
person_test = np.load("data/person_test.npy")

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 25, 1000)
# Test data shape: (443, 25, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %%
# transform data into pytorch form
# extract first 22 signals out of 25 signals
X_train_valid = X_train_valid[:, :22, :]
X_train = X_train_valid[training_index]
X_valid = X_train_valid[valid_index]
X_test = X_test[:, :22, :]

# standardize data
X_train = X_train.reshape((1715, 22*1000))
X_valid = X_valid.reshape((400, 22*1000))
X_test = X_test.reshape((443, 22*1000))

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

X_train = X_train.reshape((1715, 22, 1000))
X_valid = X_valid.reshape((400, 22, 1000))
X_test = X_test.reshape((443, 22, 1000))

# sliding window process
X_train = sliding_window(window_length, window_step, X_train)
X_valid = sliding_window(window_length, window_step, X_valid)
X_test = sliding_window(window_length, window_step, X_test)


y_train = y_train_valid[training_index]
y_valid = y_train_valid[valid_index]


trainset = torch.utils.data.TensorDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train - 769).long())
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

validset = torch.utils.data.TensorDataset(torch.from_numpy(X_valid).float(), torch.from_numpy(y_valid - 769).long())
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size, shuffle=False, num_workers=2)

testset = torch.utils.data.TensorDataset(torch.from_numpy(X_test).float(), torch.from_numpy(y_test - 769).long())
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# %%
# network architecture
class eeg_lstm(nn.Module):
     def __init__(self, in_feature=22, hidden_feature=32, num_class=4, signal_length=1000):
          super(eeg_lstm, self).__init__()
          self.rnn = nn.LSTM(input_size=in_feature, hidden_size=hidden_feature, num_layers=1) #using 5 layers lstm
          self.relu = nn.ReLU()
          self.dropout = nn.Dropout(0.5)
          self.classifier = nn.Linear(hidden_feature*signal_length, num_class) #using linear to classify the output
          
     def forward(self, x):
          out, _ = self.rnn(x) #使用默认的隐藏状态，得到的out是（1000， batch， hidden_feature）
          #print(out.shape)
          out = self.dropout(out)
          out = self.relu(out)
          out = self.dropout(out)
          #out = out[-101:-1,:,:]#取序列中的最后一个，大小是（batch， hidden_feature)
          out = flatten(out.permute(1, 0, 2))
          #print(out.shape)
          out = self.classifier(out) #得到分类结果
          #tag_score = F.log_softmax(out, dim=1)
          return out

# %%
# initiate lstm network
model = eeg_lstm(signal_length=X_train.shape[2])   
if use_gpu:
    model = model.cuda()


# define loss function and optimizer
criterion = nn.CrossEntropyLoss()
# parameters in Adam could be tuned
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=betas, weight_decay=weight_decay)

# %%
# start training and evaluating models
for epoch in range(num_epoches):  # again, normally you would NOT do 300 epochs, it is toy data
    model.train()
    print('epoch {}'.format(epoch + 1))
    print('*' * 10)
    running_loss = 0.0
    running_acc = 0.0
    for batch_idx, (signals, tags) in enumerate(trainloader):
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        model.zero_grad()

        # Step 2. Get our inputs ready for the network, that is, turn them into
        # Tensors of word indices.
        signals = signals.squeeze(1)
        signals = signals.permute(2, 0, 1)
        if use_gpu:
            signals = Variable(signals).cuda()
            tags = Variable(tags).cuda()
        else:
            signals = Variable(signals)
            tags = Variable(tags)

        # Step 3. Run our forward pass.
        tag_scores = model(signals)
        
        # Step 4. Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()
        loss = criterion(tag_scores, tags)
        running_loss += loss.data.item() * tags.size(0)
        _, pred = torch.max(tag_scores, 1)
        num_correct = (pred == tags).sum()
        running_acc += num_correct.data.item()
        # 向后传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print('Finish {} epoch, Loss: {:.6f}, Acc: {:.6f}'.format(
        epoch + 1, running_loss / (len(X_train)), running_acc / (len(
            X_train))))
    train_acc.append(running_acc / (len(X_train)))
    
    model.eval()
    eval_loss = 0.
    eval_acc = 0.
    for batch_idx, (signals, tags) in enumerate(validloader):
        
        signals = signals.squeeze(1)
        signals = signals.permute(2, 0, 1)
        if use_gpu:
            signals = Variable(signals).cuda()
            tags = Variable(tags).cuda()
        else:
            signals = Variable(signals)
            tags = Variable(tags)

        tag_scores = model(signals)
        loss = criterion(tag_scores, tags)
        eval_loss += loss.data.item() * tags.size(0)
        _, pred = torch.max(tag_scores, 1)
        num_correct = (pred == tags).sum()
        eval_acc += num_correct.data.item()
    print('Validation Loss: {:.6f}, Acc: {:.6f}'.format(eval_loss / (len(
        X_valid)), eval_acc / (len(X_valid))))
    test_acc.append(eval_acc / (len(X_valid)))
    print()

plot_acc(train_acc, test_acc)    

file = open('standardize_sliding_window.txt', 'a+')
s = ""
for e in test_acc:
  s+=str(e)
  s+=','
s+='\n'
file.writelines(s)
file.close()

eval_loss = 0.
eval_acc = 0.
for batch_idx, (signals, tags) in enumerate(testloader):
        
    signals = signals.squeeze(1)
    signals = signals.permute(2, 0, 1)
    if use_gpu:
        signals = Variable(signals).cuda()
        tags = Variable(tags).cuda()
    else:
        signals = Variable(signals)
        tags = Variable(tags)

    tag_scores = model(signals)
    loss = criterion(tag_scores, tags)
    eval_loss += loss.data.item() * tags.size(0)
    _, pred = torch.max(tag_scores, 1)
    num_correct = (pred == tags).sum()
    eval_acc += num_correct.data.item()
print('Test Loss: {:.6f}, Acc: {:.6f}'.format(eval_loss / (len(
        X_test)), eval_acc / (len(X_test))))
print()
# Out:
# epoch 1
# **********
# Finish 1 epoch, Loss: 1.374890, Acc: 0.292128
# Validation Loss: 1.352656, Acc: 0.322500
#
# epoch 2
# **********
# Finish 2 epoch, Loss: 1.298983, Acc: 0.412245
# Validation Loss: 1.329040, Acc: 0.345000
#
# epoch 3
# **********
# Finish 3 epoch, Loss: 1.242081, Acc: 0.438484
# Validation Loss: 1.303065, Acc: 0.387500
#
# epoch 4
# **********
# Finish 4 epoch, Loss: 1.196623, Acc: 0.467055
# Validation Loss: 1.273325, Acc: 0.410000
#
# epoch 5
# **********
# Finish 5 epoch, Loss: 1.152106, Acc: 0.513120
# Validation Loss: 1.254922, Acc: 0.452500
#
# epoch 6
# **********
# Finish 6 epoch, Loss: 1.108793, Acc: 0.531195
# Validation Loss: 1.231736, Acc: 0.447500
#
# epoch 7
# **********
# Finish 7 epoch, Loss: 1.095242, Acc: 0.535277
# Validation Loss: 1.197951, Acc: 0.487500
#
# epoch 8
# **********
# Finish 8 epoch, Loss: 1.044571, Acc: 0.562099
# Validation Loss: 1.178534, Acc: 0.472500
#
# epoch 9
# **********
# Finish 9 epoch, Loss: 1.003662, Acc: 0.590087
# Validation Loss: 1.197313, Acc: 0.497500
#
# epoch 10
# **********
# Finish 10 epoch, Loss: 0.950263, Acc: 0.609913
# Validation Loss: 1.152759, Acc: 0.517500
#
# epoch 11
# **********
# Finish 11 epoch, Loss: 0.929960, Acc: 0.629738
# Validation Loss: 1.152060, Acc: 0.520000
#
# epoch 12
# **********
# Finish 12 epoch, Loss: 0.914760, Acc: 0.632653
# Validation Loss: 1.137771, Acc: 0.500000
#
# epoch 13
# **********
# Finish 13 epoch, Loss: 0.894222, Acc: 0.623907
# Validation Loss: 1.112636, Acc: 0.527500
#
# epoch 14
# **********
# Finish 14 epoch, Loss: 0.861532, Acc: 0.663557
# Validation Loss: 1.105889, Acc: 0.537500
#
# epoch 15
# **********
# Finish 15 epoch, Loss: 0.862588, Acc: 0.661224
# Validation Loss: 1.102454, Acc: 0.547500
#
# epoch 16
# **********
# Finish 16 epoch, Loss: 0.849376, Acc: 0.661808
# Validation Loss: 1.099867, Acc: 0.535000
#
# epoch 17
# **********
# Finish 17 epoch, Loss: 0.828791, Acc: 0.676385
# Validation Loss: 1.112385, Acc: 0.542500
#
# epoch 18
# **********
# Finish 18 epoch, Loss: 0.834431, Acc: 0.658892
# Validation Loss: 1.108838, Acc: 0.537500
#
# epoch 19
# **********
# Finish 19 epoch, Loss: 0.827828, Acc: 0.684548
# Validation Loss: 1.086993, Acc: 0.552500
#
# epoch 20
# **********
# Finish 20 epoch, Loss: 0.791879, Acc: 0.707289
# Validation Loss: 1.096224, Acc: 0.552500
#
# epoch 21
# **********
# Finish 21 epoch, Loss: 0.794005, Acc: 0.690379
# Validation Loss: 1.104214, Acc: 0.545000
#
# epoch 22
# **********
# Finish 22 epoch, Loss: 0.758184, Acc: 0.706706
# Validation Loss: 1.100328, Acc: 0.540000
#
# epoch 23
# **********
# Finish 23 epoch, Loss: 0.746733, Acc: 0.706122
# Validation Loss: 1.087809, Acc: 0.537500
#
# epoch 24
# **********
# Finish 24 epoch, Loss: 0.726554, Acc: 0.713703
# Validation Loss: 1.104355, Acc: 0.540000
#
# epoch 25
# **********
# Finish 25 epoch, Loss: 0.724065, Acc: 0.718950
# Validation Loss: 1.093374, Acc: 0.567500
#
# epoch 26
# **********
# Finish 26 epoch, Loss: 0.749679, Acc: 0.704956
# Validation Loss: 1.091199, Acc: 0.557500
#
# epoch 27
# **********
# Finish 27 epoch, Loss: 0.727968, Acc: 0.714869
# Validation Loss: 1.079952, Acc: 0.570000
#
# epoch 28
# **********
# Finish 28 epoch, Loss: 0.713951, Acc: 0.724198
# Validation Loss: 1.084036, Acc: 0.560000
#
# epoch 29
# **********
# Finish 29 epoch, Loss: 0.713825, Acc: 0.715452
# Validation Loss: 1.092092, Acc: 0.562500
#
# epoch 30
# **********
# Finish 30 epoch, Loss: 0.705309, Acc: 0.718367
# Validation Loss: 1.105501, Acc: 0.557500
#
# epoch 31
# **********
# Finish 31 epoch, Loss: 0.720376, Acc: 0.721283
# Validation Loss: 1.101790, Acc: 0.570000
#
# epoch 32
# **********
# Finish 32 epoch, Loss: 0.678856, Acc: 0.736443
# Validation Loss: 1.076977, Acc: 0.562500
#
# epoch 33
# **********
# Finish 33 epoch, Loss: 0.645266, Acc: 0.746356
# Validation Loss: 1.096232, Acc: 0.550000
#
# epoch 34
# **********
# Finish 34 epoch, Loss: 0.649518, Acc: 0.744023
# Validation Loss: 1.132936, Acc: 0.527500
#
# epoch 35
# **********
# Finish 35 epoch, Loss: 0.653018, Acc: 0.744606
# Validation Loss: 1.083412, Acc: 0.560000
#
# epoch 36
# **********
# Finish 36 epoch, Loss: 0.651910, Acc: 0.745190
# Validation Loss: 1.116488, Acc: 0.565000
#
# epoch 37
# **********
# Finish 37 epoch, Loss: 0.632752, Acc: 0.749854
# Validation Loss: 1.086189, Acc: 0.575000
#
# epoch 38
# **********
# Finish 38 epoch, Loss: 0.620786, Acc: 0.756268
# Validation Loss: 1.109702, Acc: 0.575000
#
# epoch 39
# **********
# Finish 39 epoch, Loss: 0.633466, Acc: 0.752187
# Validation Loss: 1.103681, Acc: 0.560000
#
# epoch 40
# **********
# Finish 40 epoch, Loss: 0.603380, Acc: 0.766181
# Validation Loss: 1.117155, Acc: 0.575000
#
# epoch 41
# **********
# Finish 41 epoch, Loss: 0.619147, Acc: 0.760933
# Validation Loss: 1.116810, Acc: 0.587500
#
# epoch 42
# **********
# Finish 42 epoch, Loss: 0.594343, Acc: 0.773761
# Validation Loss: 1.107151, Acc: 0.567500
#
# epoch 43
# **********
# Finish 43 epoch, Loss: 0.573450, Acc: 0.778426
# Validation Loss: 1.147495, Acc: 0.567500
#
# epoch 44
# **********
# Finish 44 epoch, Loss: 0.576647, Acc: 0.766181
# Validation Loss: 1.120425, Acc: 0.585000
#
# epoch 45
# **********
# Finish 45 epoch, Loss: 0.560585, Acc: 0.779592
# Validation Loss: 1.114135, Acc: 0.567500
#
# epoch 46
# **********
# Finish 46 epoch, Loss: 0.565832, Acc: 0.776676
# Validation Loss: 1.120113, Acc: 0.575000
#
# epoch 47
# **********
# Finish 47 epoch, Loss: 0.561824, Acc: 0.781924
# Validation Loss: 1.122401, Acc: 0.575000
#
# epoch 48
# **********
# Finish 48 epoch, Loss: 0.563543, Acc: 0.781924
# Validation Loss: 1.132096, Acc: 0.575000
#
# epoch 49
# **********
# Finish 49 epoch, Loss: 0.531443, Acc: 0.797085
# Validation Loss: 1.122724, Acc: 0.582500
#
# epoch 50
# **********
# Finish 50 epoch, Loss: 0.555690, Acc: 0.781924
# Validation Loss: 1.134921, Acc: 0.595000
#
# epoch 51
# **********
# Finish 51 epoch, Loss: 0.529734, Acc: 0.795918
# Validation Loss: 1.105541, Acc: 0.580000
#
# epoch 52
# **********
# Finish 52 epoch, Loss: 0.548916, Acc: 0.777259
# Validation Loss: 1.123134, Acc: 0.562500
#
# epoch 53
# **********
# Finish 53 epoch, Loss: 0.528055, Acc: 0.797085
# Validation Loss: 1.103591, Acc: 0.585000
#
# epoch 54
# **********
# Finish 54 epoch, Loss: 0.520198, Acc: 0.805831
# Validation Loss: 1.105853, Acc: 0.565000
#
# epoch 55
# **********
# Finish 55 epoch, Loss: 0.528528, Acc: 0.795335
# Validation Loss: 1.132004, Acc: 0.582500
#
# epoch 56
# **********
# Finish 56 epoch, Loss: 0.510419, Acc: 0.815160
# Validation Loss: 1.120449, Acc: 0.580000
#
# epoch 57
# **********
# Finish 57 epoch, Loss: 0.508840, Acc: 0.805248
# Validation Loss: 1.114799, Acc: 0.587500
#
# epoch 58
# **********
# Finish 58 epoch, Loss: 0.505692, Acc: 0.797668
# Validation Loss: 1.146758, Acc: 0.580000
#
# epoch 59
# **********
# Finish 59 epoch, Loss: 0.512992, Acc: 0.802332
# Validation Loss: 1.184371, Acc: 0.557500
#
# epoch 60
# **********
# Finish 60 epoch, Loss: 0.531064, Acc: 0.799417
# Validation Loss: 1.136171, Acc: 0.585000
#
# epoch 61
# **********
# Finish 61 epoch, Loss: 0.528116, Acc: 0.803499
# Validation Loss: 1.129143, Acc: 0.587500
#
# epoch 62
# **********
# Finish 62 epoch, Loss: 0.491089, Acc: 0.812245
# Validation Loss: 1.122439, Acc: 0.575000
#
# epoch 63
# **********
# Finish 63 epoch, Loss: 0.481175, Acc: 0.819825
# Validation Loss: 1.148850, Acc: 0.572500
#
# epoch 64
# **********
# Finish 64 epoch, Loss: 0.465090, Acc: 0.822741
# Validation Loss: 1.120216, Acc: 0.582500
#
# epoch 65
# **********
# Finish 65 epoch, Loss: 0.450173, Acc: 0.826822
# Validation Loss: 1.148323, Acc: 0.582500
#
# epoch 66
# **********
# Finish 66 epoch, Loss: 0.452807, Acc: 0.825656
# Validation Loss: 1.156542, Acc: 0.590000
#
# epoch 67
# **********
# Finish 67 epoch, Loss: 0.465281, Acc: 0.818659
# Validation Loss: 1.178508, Acc: 0.562500
#
# epoch 68
# **********
# Finish 68 epoch, Loss: 0.483332, Acc: 0.811079
# Validation Loss: 1.148332, Acc: 0.577500
#
# epoch 69
# **********
# Finish 69 epoch, Loss: 0.461908, Acc: 0.821574
# Validation Loss: 1.133660, Acc: 0.580000
#
# epoch 70
# **********
# Finish 70 epoch, Loss: 0.457893, Acc: 0.834985
# Validation Loss: 1.178116, Acc: 0.577500
#
# epoch 71
# **********
# Finish 71 epoch, Loss: 0.453927, Acc: 0.819825
# Validation Loss: 1.190603, Acc: 0.570000
#
# epoch 72
# **********
# Finish 72 epoch, Loss: 0.462347, Acc: 0.811079
# Validation Loss: 1.140275, Acc: 0.585000
#
# epoch 73
# **********
# Finish 73 epoch, Loss: 0.448449, Acc: 0.822157
# Validation Loss: 1.159342, Acc: 0.580000
#
# epoch 74
# **********
# Finish 74 epoch, Loss: 0.449233, Acc: 0.833819
# Validation Loss: 1.202571, Acc: 0.577500
#
# epoch 75
# **********
# Finish 75 epoch, Loss: 0.461303, Acc: 0.820408
# Validation Loss: 1.196011, Acc: 0.580000
#
# epoch 76
# **********
# Finish 76 epoch, Loss: 0.427306, Acc: 0.834985
# Validation Loss: 1.171400, Acc: 0.585000
#
# epoch 77
# **********
# Finish 77 epoch, Loss: 0.429435, Acc: 0.834985
# Validation Loss: 1.184396, Acc: 0.590000
#
# epoch 78
# **********
# Finish 78 epoch, Loss: 0.440919, Acc: 0.823907
# Validation Loss: 1.165397, Acc: 0.595000
#
# epoch 79
# **********
# Finish 79 epoch, Loss: 0.421700, Acc: 0.838484
# Validation Loss: 1.191643, Acc: 0.575000
#
# epoch 80
# **********
# Finish 80 epoch, Loss: 0.422323, Acc: 0.837318
# Validation Loss: 1.167407, Acc: 0.580000
#
# epoch 81
# **********
# Finish 81 epoch, Loss: 0.427335, Acc: 0.830321
# Validation Loss: 1.172081, Acc: 0.580000
#
# epoch 82
# **********
# Finish 82 epoch, Loss: 0.432190, Acc: 0.828571
# Validation Loss: 1.205406, Acc: 0.565000
#
# epoch 83
# **********
# Finish 83 epoch, Loss: 0.418587, Acc: 0.834985
# Validation Loss: 1.190464, Acc: 0.572500
#
# epoch 84
# **********
# Finish 84 epoch, Loss: 0.408322, Acc: 0.847230
# Validation Loss: 1.234181, Acc: 0.550000
#
# epoch 85
# **********
# Finish 85 epoch, Loss: 0.422144, Acc: 0.843732
# Validation Loss: 1.211745, Acc: 0.570000
#
# epoch 86
# **********
# Finish 86 epoch, Loss: 0.386903, Acc: 0.848980
# Validation Loss: 1.263940, Acc: 0.575000
#
# epoch 87
# **********
# Finish 87 epoch, Loss: 0.406949, Acc: 0.836735
# Validation Loss: 1.238569, Acc: 0.580000
#
# epoch 88
# **********
# Finish 88 epoch, Loss: 0.391882, Acc: 0.840233
# Validation Loss: 1.234217, Acc: 0.555000
#
# epoch 89
# **********
# Finish 89 epoch, Loss: 0.397472, Acc: 0.861224
# Validation Loss: 1.208930, Acc: 0.582500
#
# epoch 90
# **********
# Finish 90 epoch, Loss: 0.409038, Acc: 0.837318
# Validation Loss: 1.250432, Acc: 0.565000
#
# epoch 91
# **********
# Finish 91 epoch, Loss: 0.420645, Acc: 0.839650
# Validation Loss: 1.211780, Acc: 0.572500
#
# epoch 92
# **********
# Finish 92 epoch, Loss: 0.409206, Acc: 0.850146
# Validation Loss: 1.211569, Acc: 0.577500
#
# epoch 93
# **********
# Finish 93 epoch, Loss: 0.410884, Acc: 0.835569
# Validation Loss: 1.214113, Acc: 0.557500
#
# epoch 94
# **********
# Finish 94 epoch, Loss: 0.381643, Acc: 0.860058
# Validation Loss: 1.257522, Acc: 0.545000
#
# epoch 95
# **********
# Finish 95 epoch, Loss: 0.392605, Acc: 0.842566
# Validation Loss: 1.235154, Acc: 0.565000
#
# epoch 96
# **********
# Finish 96 epoch, Loss: 0.370916, Acc: 0.859475
# Validation Loss: 1.244364, Acc: 0.572500
#
# epoch 97
# **********
# Finish 97 epoch, Loss: 0.366785, Acc: 0.855977
# Validation Loss: 1.270072, Acc: 0.550000
#
# epoch 98
# **********
# Finish 98 epoch, Loss: 0.364269, Acc: 0.856560
# Validation Loss: 1.252819, Acc: 0.565000
#
# epoch 99
# **********
# Finish 99 epoch, Loss: 0.383519, Acc: 0.851312
# Validation Loss: 1.253997, Acc: 0.560000
#
# epoch 100
# **********
# Finish 100 epoch, Loss: 0.378779, Acc: 0.855977
# Validation Loss: 1.270524, Acc: 0.577500
# Test Loss: 1.199398, Acc: 0.591422
